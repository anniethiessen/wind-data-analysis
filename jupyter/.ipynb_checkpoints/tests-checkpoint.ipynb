# %% [markdown]
# ## IMPORTS

# %%
import glob
import os

import pandas as pd

# %% [markdown]
# ## GLOBALS

# %%
SCENARIO_CODES = {
    'business_as_usual_5%': '5BAU',
    'concentrated_20%': '20CONC',
    'dispersed_20%': '20DISP',
    'targeted_35%': '35TRGT'
}
FORECAST_CODES = {
    'actual': 'Pwr1HB',
    'forecast_one_hour': 'FcstHA',
    'forecast_four_hour': 'Fcst4HA',
    'forecast_six_hour': 'Fcst6HA',
    'forecast_one_day': 'FcstDA'
}

# ROOT_DIR = 'data'
ROOT_DIR = 'data/test'
PERIOD_DIRS = ['2008-2010']
SCENARIO_DIRS = [
    SCENARIO_CODES['business_as_usual_5%'],
    SCENARIO_CODES['concentrated_20%'],
    SCENARIO_CODES['dispersed_20%'],
    SCENARIO_CODES['targeted_35%']
]
FORECAST_DIRS = [
    FORECAST_CODES['actual'],
    FORECAST_CODES['forecast_one_hour'],
    FORECAST_CODES['forecast_four_hour'],
    FORECAST_CODES['forecast_six_hour'],
    FORECAST_CODES['forecast_one_day']
]

# %% [markdown]
# ## UTILS

# %% [markdown]
# #### GET CSV FILE PATHS

# %%
def get_file_paths(period_dirs, scenario_dirs, forecast_dirs):
    """
    Returns a list of CSV file paths within specific period, scenario,
    and forecast directories.

    :param period_dirs: Period directory names
    :type period_dirs: list
    :param scenario_dirs: Scenario directory names
    :type scenario_dirs: list
    :param forecast_dirs: Forecast directory names
    :type forecast_dirs: list
    :return: CSV file paths
    :rtype: list

    """

    ret = []
    for period_dir in period_dirs:
        for scenario_dir in scenario_dirs:
            for forecast_dir in forecast_dirs:
                data_path = '../{r}/{p}/{s}/{f}/'.format(
                    r=ROOT_DIR, p=period_dir, s=scenario_dir, f=forecast_dir)
                ret += glob.glob(os.path.join(data_path, "*.csv"))
    return ret

# %% [markdown]
# #### GET DATAFRAMES

# %%
def get_dataframes(file_paths):
    """
    Returns a dictionary of dataframes from list of CSV file paths.

    :param file_paths: CSV file paths
    :type file_paths: list
    :return: Dataframes
    :rtype: dict

    """

    ret = {}
    for file_path in file_paths:
        df = pd.read_csv(file_path)
        file_name = os.path.splitext(os.path.basename(file_path))[0]
        ret[file_name] = df
    return ret

# %% [markdown]
# #### PRINT HEADS

# %%
def print_heads(data_dict):
    """
    Prints file name and dataframe head (first five rows) from data 
    dictionary.
    
    :param data_dict: File names with dataframes
    :type data_dict: dict
    
    """
    
    for file_name, df in data_dict.items():
        print('\n' + file_name + '\n')
        print(df.head())

# %% [markdown]
# ## TESTS

# %% [markdown]
# ### PRINT SELECTED HEADS

# %%
def print_select_heads(period_dirs, scenario_dirs, forecast_dirs):
    print_heads(get_dataframes(get_file_paths(period_dirs, scenario_dirs, forecast_dirs)))

# %% [markdown]
# #### PRINT ALL HEADS

# %%
period_dirs = PERIOD_DIRS
scenario_dirs = SCENARIO_DIRS
forecast_dirs = FORECAST_DIRS
print_select_heads(period_dirs, scenario_dirs, forecast_dirs)
# Out:
# 0004Pwr1HB
#
#             PlantID =                4
# 0         Plant Cap =          320.000
# 1           Date/Time            Value
# 2  01/01/2008 00:00:00           4.318
# 3  01/01/2008 01:00:00          34.771
# 4  01/01/2008 02:00:00          82.155
#
# 0003Pwr1HB
#
#             PlantID =                3
# 0         Plant Cap =          128.000
# 1           Date/Time            Value
# 2  01/01/2008 00:00:00           0.989
# 3  01/01/2008 01:00:00          11.727
# 4  01/01/2008 02:00:00          27.144
#
# 0006Pwr1HB
#
#             PlantID =                6
# 0         Plant Cap =          272.000
# 1           Date/Time            Value
# 2  01/01/2008 00:00:00           0.691
# 3  01/01/2008 01:00:00          21.632
# 4  01/01/2008 02:00:00          55.332
#
# 0003FcstHA
#
#             PlantID =                   3
# 0         Plant Cap =             128.000
# 1           Date/Time               Value
# 2  01/01/2008 00:00:00          61.802295
# 3  01/01/2008 01:00:00          57.062765
# 4  01/01/2008 02:00:00           0.312807
#
# 0004FcstHA
#
#             PlantID =                   4
# 0         Plant Cap =             320.000
# 1           Date/Time               Value
# 2  01/01/2008 00:00:00         263.351991
# 3  01/01/2008 01:00:00         259.161283
# 4  01/01/2008 02:00:00           1.635371
#
# 0006FcstHA
#
#             PlantID =                   6
# 0         Plant Cap =             272.000
# 1           Date/Time               Value
# 2  01/01/2008 00:00:00         221.417100
# 3  01/01/2008 01:00:00         190.200238
# 4  01/01/2008 02:00:00           0.050080
#
# 0006Fcst4HA
#
#             PlantID =                   6
# 0         Plant Cap =             272.000
# 1           Date/Time               Value
# 2  01/01/2008 00:00:00         104.049178
# 3  01/01/2008 01:00:00         113.906687
# 4  01/01/2008 02:00:00          87.386010
#
# 0003Fcst4HA
#
#             PlantID =                   3
# 0         Plant Cap =             128.000
# 1           Date/Time               Value
# 2  01/01/2008 00:00:00          38.450814
# 3  01/01/2008 01:00:00          48.020550
# 4  01/01/2008 02:00:00          41.286550
#
# 0004Fcst4HA
#
#             PlantID =                   4
# 0         Plant Cap =             320.000
# 1           Date/Time               Value
# 2  01/01/2008 00:00:00         132.014329
# 3  01/01/2008 01:00:00         153.648240
# 4  01/01/2008 02:00:00         111.163712
#
# 0006Fcst6HA
#
#             PlantID =                   6
# 0         Plant Cap =             272.000
# 1           Date/Time               Value
# 2  01/01/2008 00:00:00          82.042672
# 3  01/01/2008 01:00:00          99.601652
# 4  01/01/2008 02:00:00         103.761510
#
# 0003Fcst6HA
#
#             PlantID =                   3
# 0         Plant Cap =             128.000
# 1           Date/Time               Value
# 2  01/01/2008 00:00:00          34.072409
# 3  01/01/2008 01:00:00          46.325130
# 4  01/01/2008 02:00:00          48.969160
#
# 0004Fcst6HA
#
#             PlantID =                   4
# 0         Plant Cap =             320.000
# 1           Date/Time               Value
# 2  01/01/2008 00:00:00         107.388515
# 3  01/01/2008 01:00:00         133.864570
# 4  01/01/2008 02:00:00         131.700276
#
# 0003FcstDA
#
#             PlantID =                   3
# 0         Plant Cap =             128.000
# 1           Date/Time               Value
# 2  01/01/2008 00:00:00          32.612942
# 3  01/01/2008 01:00:00          45.760000
# 4  01/01/2008 02:00:00          51.530000
#
# 0004FcstDA
#
#             PlantID =                   4
# 0         Plant Cap =             320.000
# 1           Date/Time               Value
# 2  01/01/2008 00:00:00          99.179911
# 3  01/01/2008 01:00:00         127.270000
# 4  01/01/2008 02:00:00         138.545808
#
# 0006FcstDA
#
#             PlantID =                   6
# 0         Plant Cap =             272.000
# 1           Date/Time               Value
# 2  01/01/2008 00:00:00          74.707183
# 3  01/01/2008 01:00:00          94.833307
# 4  01/01/2008 02:00:00         109.220000
#
# 0011Pwr1HB
#
#             PlantID =                  11
# 0         Plant Cap =             400.000
# 1           Date/Time               Value
# 2  01/01/2008 00:00:00           2.435738
# 3  01/01/2008 01:00:00          39.073467
# 4  01/01/2008 02:00:00         124.405890
#
# 0014Pwr1HB
#
#             PlantID =                  14
# 0         Plant Cap =             400.000
# 1           Date/Time               Value
# 2  01/01/2008 00:00:00           1.690418
# 3  01/01/2008 01:00:00          28.366512
# 4  01/01/2008 02:00:00         103.078891
#
# 0007Pwr1HB
#
#             PlantID =                   7
# 0         Plant Cap =             400.000
# 1           Date/Time               Value
# 2  01/01/2008 00:00:00           2.463111
# 3  01/01/2008 01:00:00          41.089439
# 4  01/01/2008 02:00:00         107.868868
#
# 0011FcstHA
#
#             PlantID =                  11
# 0         Plant Cap =             400.000
# 1           Date/Time               Value
# 2  01/01/2008 00:00:00         391.733357
# 3  01/01/2008 01:00:00         399.368074
# 4  01/01/2008 02:00:00           1.205348
#
# 0007FcstHA
#
#             PlantID =                   7
# 0         Plant Cap =             400.000
# 1           Date/Time               Value
# 2  01/01/2008 00:00:00         396.398512
# 3  01/01/2008 01:00:00         399.195309
# 4  01/01/2008 02:00:00           0.853430
#
# 0014FcstHA
#
#             PlantID =                  14
# 0         Plant Cap =             400.000
# 1           Date/Time               Value
# 2  01/01/2008 00:00:00         362.875739
# 3  01/01/2008 01:00:00         356.102366
# 4  01/01/2008 02:00:00           0.706316
#
# 0007Fcst4HA
#
#             PlantID =                   7
# 0         Plant Cap =             400.000
# 1           Date/Time               Value
# 2  01/01/2008 00:00:00         177.618543
# 3  01/01/2008 01:00:00         201.007050
# 4  01/01/2008 02:00:00         137.098710
#
# 0011Fcst4HA
#
#             PlantID =                  11
# 0         Plant Cap =             400.000
# 1           Date/Time               Value
# 2  01/01/2008 00:00:00         177.242660
# 3  01/01/2008 01:00:00         202.489640
# 4  01/01/2008 02:00:00         136.889050
#
# 0014Fcst4HA
#
#             PlantID =                  14
# 0         Plant Cap =             400.000
# 1           Date/Time               Value
# 2  01/01/2008 00:00:00         167.407140
# 3  01/01/2008 01:00:00         188.820480
# 4  01/01/2008 02:00:00         131.157270
#
# 0007Fcst6HA
#
#             PlantID =                   7
# 0         Plant Cap =             400.000
# 1           Date/Time               Value
# 2  01/01/2008 00:00:00         136.597283
# 3  01/01/2008 01:00:00         163.846770
# 4  01/01/2008 02:00:00         162.644670
#
# 0011Fcst6HA
#
#             PlantID =                  11
# 0         Plant Cap =             400.000
# 1           Date/Time               Value
# 2  01/01/2008 00:00:00         137.025650
# 3  01/01/2008 01:00:00         165.574900
# 4  01/01/2008 02:00:00         162.329780
#
# 0014Fcst6HA
#
#             PlantID =                  14
# 0         Plant Cap =             400.000
# 1           Date/Time               Value
# 2  01/01/2008 00:00:00         130.756800
# 3  01/01/2008 01:00:00         157.455140
# 4  01/01/2008 02:00:00         155.616820
#
# 0011FcstDA
#
#             PlantID =                  11
# 0         Plant Cap =             400.000
# 1           Date/Time               Value
# 2  01/01/2008 00:00:00         123.620000
# 3  01/01/2008 01:00:00         153.270000
# 4  01/01/2008 02:00:00         170.810000
#
# 0007FcstDA
#
#             PlantID =                   7
# 0         Plant Cap =             400.000
# 1           Date/Time               Value
# 2  01/01/2008 00:00:00         122.923539
# 3  01/01/2008 01:00:00         151.460000
# 4  01/01/2008 02:00:00         171.160000
#
# 0014FcstDA
#
#             PlantID =                  14
# 0         Plant Cap =             400.000
# 1           Date/Time               Value
# 2  01/01/2008 00:00:00         118.540000
# 3  01/01/2008 01:00:00         147.000000
# 4  01/01/2008 02:00:00         163.770000
#
# 0022Pwr1HB
#
#             PlantID =               22
# 0         Plant Cap =          192.000
# 1           Date/Time            Value
# 2  01/01/2008 00:00:00           1.589
# 3  01/01/2008 01:00:00          18.223
# 4  01/01/2008 02:00:00          55.855
#
# 0022FcstHA
#
#             PlantID =                  22
# 0         Plant Cap =             192.000
# 1           Date/Time               Value
# 2  01/01/2008 00:00:00         187.602602
# 3  01/01/2008 01:00:00         191.173716
# 4  01/01/2008 02:00:00           0.500219
#
# 0022Fcst4HA
#
#             PlantID =                  22
# 0         Plant Cap =             192.000
# 1           Date/Time               Value
# 2  01/01/2008 00:00:00          83.400530
# 3  01/01/2008 01:00:00          95.282750
# 4  01/01/2008 02:00:00          63.052040
#
# 0022Fcst6HA
#
#             PlantID =                  22
# 0         Plant Cap =             192.000
# 1           Date/Time               Value
# 2  01/01/2008 00:00:00          63.862620
# 3  01/01/2008 01:00:00          77.303180
# 4  01/01/2008 02:00:00          74.780500
#
# 0022FcstDA
#
#             PlantID =                  22
# 0         Plant Cap =             192.000
# 1           Date/Time               Value
# 2  01/01/2008 00:00:00          57.350000
# 3  01/01/2008 01:00:00          71.310000
# 4  01/01/2008 02:00:00          78.690000
